# %%
import re
import requests

import pandas as pd
import os

from bs4 import BeautifulSoup
bacteria_regex = r'(?P<bacterium>[A-Z]\. [a-z]+)(?P<strain>\s?[A-Z]+\s?[0-9]+)?'

# %%
SAVE_FILES = False

# %%
def get_sequence(sequence_string):
    return sequence_string

def get_references(reference_string, reference_link):
    reference = reference_string
    if reference_link:
        reference += ' | ' + reference_link
    return [reference]

def get_data(data_string):

    all_bacteria = {}
    unit_strings = ['uM', 'ug/ml']
    unit_delimiters = [u + ')' for u in unit_strings]
    unit_regex_pattern = '(' + '|'.join(map(re.escape, unit_delimiters)) + ')'
    fields = re.split(unit_regex_pattern, data_string)
    fields_and_units = []
    for i, f in enumerate(fields[:-1]):  # Parentheses around regex mean match expression is also returned
        # Up to -1 to skip the last one, which has no corresponding unit match
        if i % 2 == 0:
            fields_and_units.append({'bacteria_string': f, 'unit': fields[i+1]})

    for field_and_unit in fields_and_units:

        bacteria_string = field_and_unit['bacteria_string']
        unit = field_and_unit['unit']
        
        bacteria_matches = re.finditer(bacteria_regex, bacteria_string)
        
        def _extract_value(range_expr):
            if '-' not in range_expr:
                return range_expr
            bounds = range_expr.split('-')

            def _geometric_mean(b0, b1):
                return (b0 * b1) ** (0.5)

            try:
                b0, b1 = float(bounds[0]), float(bounds[1])
                return str(_geometric_mean(b0, b1))  # Take geometric mean (log scale)
            except:
                print("?????")
                return bounds[0]
                
        
        numeric_range_regex = r'MIC \d+\.?\s?\-?\s?\d*'
        numeric_match = re.search(numeric_range_regex, bacteria_string)
        if not numeric_match:
            continue
        mic_match_string = numeric_match.group(0)
        numeric_part = mic_match_string[4:]
        value = _extract_value(numeric_part)
        for bacteria_match in bacteria_matches:
            bacterium = bacteria_match.groupdict()['bacterium']
            strain = bacteria_match.groupdict()['strain']
            if strain:
                strain = strain.strip()
            all_bacteria[(bacterium, strain)] = {
                'unit': unit,
                'value': value,
            }
            
    return all_bacteria

def get_modifications(modifications_string):
    modifications = []
    if re.match(r'XX[B-Z]', modifications_string):
        modifications.append('unknown_modification: XX[B-Z]')
    for bad_string in ['UCBB', 'UCSB', 'UCSS1b']:
        if bad_string in modifications_string:
            modifications.append('unknown_modification: ' + bad_string)
    if 'UCSS1a' in modifications_string or 'S=S' in modifications_string or 'S-S' in modifications_string:
        modifications.append('disulfide')
    if 'XXA' in modifications_string:
        modifications.append('C-Terminal')
    return modifications

# %%
def get_data_from_rows(rows):
    row_names = ["Hemolytik ID", 
                 "PMID", 
                 "YEAR", 
                 "SEQUENCE", 
                 "LENGTH", 
                 "NAME", 
                 "C-ter Modification", 
                 "N-ter Modification", 
                 "Linear/Cyclic",
                 "Stereochemistry",
                 "Non-Natural",
                 "NATURE",
                 "ACTIVITY",
                 "RBCs SOURCE"]
    output = {}
    for row in rows:
        for row_name in row_names:
            if row_name in row.text:
                output[row_name]=row.text.split(row_name)[1]
    
    return output

# %%
hemolytik_dir = "../../../../"
hemolytik_sequences_with_Lstereo = pd.read_csv(hemolytik_dir+"hemolytik_sequences_Lstereo.txt",sep="\t")

# %%
hemolytik_sequences_with_Lstereo.head(2)
# Out:
#      ID                           SEQ
# 0  1002  ALWMTLLKKVLKAAAKAALDAVLVGANA
# 1  1003  ALWDTLLKKVLKAAAKAALNAVLVGANA

# %%
data_ids = hemolytik_sequences_with_Lstereo.ID.values
print(data_ids[:5])
# Out:
# [1002 1003 1004 1005 1006]

# %%
DATABASE_NAME = 'Hemolytik'
url_base = 'http://crdd.osdd.net/raghava/hemolytik/display.php?details='

NUM_AMPS = len(data_ids)
amps = {}

# %%
NUM_AMPS
# Out:
# 2388

# %%
results = {}
for i in range(max(len(amps), 1), NUM_AMPS):
    if i%100==0:
        print(f"processed {i}/{NUM_AMPS}")
    id_ = data_ids[i]
    url = url_base + str(id_)
    content = requests.get(url).content

    soup = BeautifulSoup(content, 'html.parser')

    table = soup.findAll(lambda tag: tag.name=='table' and tag.has_attr("bordercolor"))# and tag.has_attr('class'))# and tag['name']=="tab") 
    rows = table[1].findAll(lambda tag: tag.name=='tr')
    table_data = get_data_from_rows(rows)
    results[id_]=table_data
# Out:
# processed 100/2388
# processed 200/2388
# processed 300/2388
# processed 400/2388
# processed 500/2388
# processed 600/2388
# processed 700/2388
# processed 800/2388
# processed 900/2388
# processed 1000/2388
# processed 1100/2388
# processed 1200/2388
# processed 1300/2388
# processed 1400/2388
# processed 1500/2388
# processed 1600/2388
# processed 1700/2388
# processed 1800/2388
# processed 1900/2388
# processed 2000/2388
# processed 2100/2388
# processed 2200/2388
# processed 2300/2388

# %%
dataframe_data = {}
for row_name in row_names:
    dataframe_data[row_name]=[]
    
for _, vd in results.items():
    for k, v in vd.items():
        dataframe_data[k].append(v)
dataframe_data = pd.DataFrame(dataframe_data)
print(f"{len(dataframe_data)=}")
print(dataframe_data.head(2))

if SAVE_FILES:
    dataframe_data.to_csv("hemolytik_seqsLstereo_unprocessed.data")
# Out:
# len(dataframe_data)=2387
#   Hemolytik ID      PMID  YEAR                      SEQUENCE LENGTH      NAME  \
# 0         1003  10660589  2000  ALWDTLLKKVLKAAAKAALNAVLVGANA     28     D4-S4
# 1         1004  10660589  2000  ALWDTLLKKVLKAAAKAALDAVLVGANA     28  D4D20-S4
#
#   C-ter Modification N-ter Modification Linear/Cyclic Stereochemistry  \
# 0               Free               Free        Linear               L
# 1               Free               Free        Linear               L
#
#   Non-Natural         NATURE         ACTIVITY RBCs SOURCE
# 0        None  Antimicrobial  LC50 =2.3±0.3μM       Human
# 1        None  Antimicrobial      LC50 =5±1μM       Human

# %%
os.getcwd()
# Out:
# '/media/jmenard/Data/projects/compare-latent-spaces-amps/oracles/Antimicrobial-Peptides/data'

# %% [markdown]
# the ACTIVITY column has variance in how it is reported, somewhat inconveniently

# %%
set(dataframe_data.ACTIVITY)
# Out:
# {'No hemolysis upto 500μM',
#  '3.5% hemolytic at 40μM',
#  '5% hemolysis at 30μM',
#  '5.07% hemolysis at 25μg/ml  ',
#  '0.08% hemolysis at 100µg/ml',
#  'HD50=77μg/ml',
#  '14% hemolysis at 200μg/ml ',
#  '9.1% hemolytic at 15.7μM',
#  '0% hemolysis at 3.13-25 μM',
#  '40% hemolysis at 400g/l',
#  '95.7±4.12% hemolysis at 100μg/ml',
#  'LD50 > 600µM',
#  'MHC <81μM',
#  '37.9% hemolysis at 50µM',
#  '0% hemolysis upto 100μg/ml ',
#  '0-5% hemolysis at 40μg/ml',
#  'LC50  >100μM',
#  '~70% hemolysis at 50μM',
#  '0% hemolysis upto 500μg/ml (non hemolytic)',
#  'EC50 = 45000 nM',
#  'HC10  = 3840 μg/ml',
#  'HD50  =8.9x103μM',
#  'HC10  = 1.78 μg/ml',
#  '0.8% hemolysis at 0.125mg/ml ',
#  'MHC =214.81μM ',
#  ' LD50 = 100µM',
#  '100%  hemolysis at 100µM',
#  '100% hemolysis at 30 µg/mL',
#  'HC10  = 203 μg/ml',
#  '0.19% hemolysis at 50μg/ml',
#  'LC50 =50μM',
#  'EC50 =80μM',
#  'EC50 = 590000 nM',
#  '>40% hemolysis at 50μM',
#  '0% hemolysis at 300μM',
#  '18% hemolysis at 10µM',
#  '100% hemolysis at 50μM',
#  'HC10  = 9350  μg/ml',
#  '40% hemolytic at 25μM at pH 5',
#  '20% hemolysis at 6.0μM',
#  'HD50 = 8.7μM ',
#  '~20% hemolysis at 5µM',
#  'Hemolytic activity expresssed as the initial rate (∆A/∆t, min- 1) i.e. at above 100 µM activity is  ~0.002 min-1',
#  '34.3% hemolysis at 200μM',
#  'MHC =1000 μg/ml',
#  '0% hemolysis  at 50 µM (non-hemolytic)',
#  '0.01 fractions hemolysis at 0.5μM  ',
#  '30% hemolysis at 6.25µM',
#  'LC50 = 27.3µM ',
#  '35% hemolysis at 75μg',
#  '0.06% hemolysis at 100µg/ml',
#  '100% hemolysis at ~25μM',
#  '100% hemolysis at >50μg/ml  ',
#  '20% hemolysis 100 µM',
#  '0.6% hemolysis at 0.0625mg/ml',
#  '4% hemolysis at 50μM  ',
#  '7.8% hemolysis at 0.25mg/ml',
#  'LC50 =28μM',
#  '0.8% hemolysis at 200μg/ml',
#  '<15% hemolysis at 500μM',
#  'LC50 =1,467μM',
#  'LC50 =10μM',
#  'MHC  <81μM',
#  '70% hemolysis at 200μM',
#  'HC50 = 80µM',
#  '93.4% hemolysis at 100µM',
#  '50% hemolysis at >900µM',
#  '~80% hemolysis at 100µM',
#  'HC10  = 13800 μg/ml',
#  '13.2% hemolytic at 31.5μM ',
#  '68±7.5% hemolysis at 360µM',
#  '2.4±0.7% hemolytic at 25μM',
#  '>20% hemolysis at 50μM',
#  '0% hemolysis at 10μg/ml (non hemolytic)',
#  '13% hemolysis at 100µg ml-1',
#  ' LD50 = 38µM',
#  'No hemolysis (Non hemolysis)',
#  'MHC =6.92μM ',
#  '64.4±2.2% hemolytic at 25μM',
#  'EC50  >36μM  ',
#  '22% hemolysis at 75μg',
#  '0% hemolysis at 1-100μM  (non-hemolytic)',
#  'LC50 = 500µM',
#  'HD50  =76μM',
#  'LC50 =1,993μM ',
#  '14.7% hemolysis at 80µg/ml',
#  '0% hemolysis at 80µg/ml',
#  '51.4±0.5% hemolysis at 22.2μM',
#  '28.8% hemolysis at 100µM',
#  '2.2% hemolysis at 0.0625mg/ml',
#  'MHC =8μg/ml',
#  '>7% hemolytic at 256mg/ml',
#  '1.01% hemolysis at 100µM ',
#  '0-3% hemolysis at 80 μg/ml',
#  '1% hemolytic at 1.25μM',
#  '>50% hemolysis at 80 μg/ml',
#  'HC50 =75μM',
#  '90% hemolysis at 100µM ',
#  '40% hemolysis at 75μg',
#  '10% hemolysis at 2.5μM',
#  'MHC =50μM',
#  '100% hemolysis at 65μg/ml',
#  '~14% hemolysis at 20μM',
#  '2.9±0.5% hemolytic at 25μM',
#  '115.7 ±2.5% hemolysis at 100µM',
#  '0% hemolysis at 200μg/ml',
#  '40-50% hemolysis at 40μg/ml',
#  'Area of inhibition ~25mm2 at 5 nmol',
#  '1±0.1% hemolysis at 360µM',
#  '50-55% hemolysis at 40 µM',
#  '~70% hemolysis at 128µM',
#  '70% hemolysis at 160μg/ml',
#  '0% hemolysis upto 1 mM',
#  '34±9.2% hemolysis at 50µM',
#  '0.32% hemolysis at 100µg/ml',
#  'EC50 = 1950µM',
#  '100% hemolysis at 80µM ',
#  'EC50 =107μM',
#  'MHC = 64μg/mL ',
#  '100% hemolysis at 225 µM',
#  '<1% hemolysis at 120μg/ml',
#  '3.4±0.7% hemolytic at 25μM',
#  'LD50 =10μM',
#  '0% hemolysis at 128µM (non-hemolytic)',
#  '1% hemolysis at 25μg/ml ',
#  '70% hemolytic at 40μM ',
#  '2.3% hemolytic at 12.5μg/ml',
#  'MHC = 5.20 ± 0.02μmol/L',
#  '0% hemolysis upto 100µM',
#  'EC50 = 610µM',
#  'Not detected hemolysis at 200µM',
#  '3% hemolysis at 100μM',
#  '0.06% hemolysis at 10μg/ml',
#  '81±3.7% hemolysis at 100µM',
#  '3% hemolysis at 200µM',
#  '<50% hemolysis at 50µM',
#  '100% hemolysis at 1μM',
#  '36 % of hemolysis at 50mM',
#  '7.61% hemolysis at 50μg/ml  ',
#  '5.13% hemolysis at 100μg/ml  ',
#  'LC50 =70μM',
#  '6% hemolysis at 30μM',
#  '43% hemolytic at 50μM',
#  '12% hemolysis at 150μM',
#  '4.90% hemolysis at 50μg/ml  ',
#  '4% hemolysis at 64μM  ',
#  '4.78% Hmolysis at 6.3μg/ml  ',
#  'LC50 = 225µM',
#  '15.4±3.5% hemolysis at 50µg/ml',
#  '41.8% hemolysis at 64μM  ',
#  'LC50 =132µM ',
#  '50% hemolytic at 16μg/ml',
#  '34% hemolysis at 200µM',
#  '~10% hemolysis at 100µg/ml',
#  '0% hemolysis at 200µM',
#  '60% hemolysis at 50μM  ',
#  '2.7 % hemolytic at 100mg/mL',
#  '0% hemolysis at 0.78µM',
#  '20% hemolysis at 250μg',
#  '~90% hemolysis at 0.8μM  ',
#  '60% hemolysis at 25μM',
#  'LD50 =135μM',
#  '4.73% hemolysis at 12.5μg/ml   ',
#  'LD50 ~0.1µM',
#  'HD50  =2.1x102μM',
#  '12% hemolysis at 50μM  ',
#  '100% hemolysis at 0.77mM  ',
#  'HD50 =7.53±0.19mM',
#  '50% hemolytic at 128μmol/L ',
#  'IC50 >>100μM',
#  '19% hemolytic at 10 μg/mL',
#  '87.2±2.6% hemolysis at 50µg/ml',
#  '60-70% hemolysis at 80μg/ml',
#  '20.0±1.8% hemolysis at 50µM',
#  'LC50 =2±0.1μM',
#  'EC50 =46μM',
#  '10% hemolysis at 38μM',
#  'Hemolytic activity i.e. 16.6HU/mg',
#  '7.2% hemolysis at 100μM',
#  '>60% hemolysis at 50μM',
#  '0.03 fractions hemolysis at 5.0μM  ',
#  '6.69±1.51% hemolysis at 100μg/ml',
#  '2.5% hemolytic at 100μM',
#  '<5% hemolytic at 100 μM',
#  '94.69% hemolysis at 100µM',
#  '0.02% hemolysis at 10µg/ml',
#  '80% hemolysis at 100µM',
#  '400μg of peptide can totally lyse 7x108 erythrocytes in 10 min at pH 5.0',
#  '0.23% hemolysis at 50μg/ml',
#  '0% hemolysis at 100μg/ml ',
#  '6.05% hemolysis at 100μg/ml  ',
#  '30.6% hemolysis at 80µg/ml',
#  'MHC =1000μg/ml',
#  '30.3% hemolysis at 100µM',
#  '50% hemolysis at 128µg/ml',
#  '0% hemolysis at 0.8μM  (non-hemolytic)',
#  '1% hemolysis at 50μg/ml',
#  '18 % of hemolysis at 50mM',
#  '88% hemolysis at 50μM  ',
#  '1.4±0.3% hemolysis at 44.5μM',
#  '80% hemolysis at 0.77mM  ',
#  'HD50  =5.35±0.60mM',
#  '1.1±0.3% hemolysis at 22.2μM',
#  '60-65% hemolysis at 160μg/ml',
#  '0% hemolysis at 1μM ',
#  '90% hemolysis at 0.77mM  ',
#  '4.90% hemolysis at 100μg/ml  ',
#  'IC50 = 26 µM',
#  'EC50 = 338µM',
#  '79±6.5% hemolysis at 100µM',
#  'MHC <125 μg/mL',
#  'MHC = 128μg/mL ',
#  'EC50 =13.1μM ',
#  '66.3% hemolysis at 1mg/ml',
#  '~80% hemolysis at 8μg',
#  '100% hemolysis at 40μM',
#  'HC50 >300µM',
#  '9.65% hemolysis at 100µM',
#  '4.1% hemolytic at 12.5μg/ml',
#  '100% hemolysis at 110μg/ml',
#  '>80% hemolysis at 50μM',
#  '~60% hemolysis at 100μM',
#  'HC10  = 6140 μg/ml',
#  'Conc. Required for hemolysis =0.6nmols',
#  '39% hemolysis at 400μM',
#  '0.41% hemolysis at 4μg/ml',
#  '20-30% hemolysis at40 µM',
#  'EC25=15μM',
#  'IC50 =32μM',
#  '38.2% hemolysis at 80µg/ml',
#  '3±0.1% hemolysis at 50µM',
#  '31% hemolysis at 12.5µM',
#  '0% hemolysis at 6.25µM',
#  'EC50 = 31 (23–41)µM',
#  '8.7% hemolysis at 32mg/ml',
#  '<10% hemolysis upto 5µM',
#  'LD50 =120μM',
#  'LC50 =105μM',
#  'LD50 = 11µM',
#  '60% hemolysis at 40μg/ml',
#  '~20% hemolysis at 100µM',
#  '9.4% hemolysis at 100µM',
#  '32% hemolysis at 400μM',
#  'LD50=28.1µM',
#  '51% hemolysis at ~20μM',
#  '2±0.7% hemolysis at 50µM',
#  'LC50  = 100μM',
#  'HC50 =11μM',
#  'EC50 >250μM',
#  '2.6% hemolytic at 50μg/ml',
#  '80% hemolysis at 40μM',
#  '10% hemolysis at 320μg/ml',
#  '21% hemolysis at 64μM  ',
#  'EC50 =5.98μM',
#  'EC50 =2.6μM',
#  ' LD50  = 65µM',
#  'LD50 =5μM',
#  '0.2% hemolytic at 100μM',
#  '65±1.5% hemolysis at 100µM',
#  '~2% hemolysis at 20μM',
#  'EC50 =26 μM',
#  '4% hemolysis at 50µM',
#  'HC50 > ~24',
#  '6±0.6% hemolysis at 50µM',
#  '91.73% hemolysis at 10μg',
#  'LD50 =65μM',
#  '32% hemolysis at 50μM',
#  'LC50 = 8μM',
#  '~90% hemolysis at 50μM',
#  '~60% hemolysis at 200 μg/ml',
#  '0.54% hemolysis at 8μg/ml',
#  '50.40% hemolysis at 100μM',
#  '3.8±0.4% hemolytic at 25μM',
#  'MHC =650μM',
#  '100% hemolysis at 48μM',
#  '0% hemolytic at 3.13μg/ml',
#  'LD50 =4.7µM',
#  '34±2.1% hemolysis at 100µM',
#  '~ 80% hemolysis at 200µg/ml',
#  '7.2% hemolytic at 10μM',
#  '~55% hemolysis at 20μM',
#  '2% hemolytic at 25mM',
#  '20% hemolysis at 100 μM',
#  '0.5% hemolytic at 1.25μM',
#  '<10% hemolysis  at 50µM',
#  'No hemolysis upto 800μg/ml',
#  'HC50 =416.4μg/ml',
#  '51% hemolysis at 100μM',
#  'HD50 =105.0μM  ',
#  'HC50 =203.3μg/ml',
#  '0% hemolysis at 14 µM',
#  '10.90% hemolysis at 100μg/ml  ',
#  'HD50=230μg/ml',
#  'MHC > 256 μM',
#  '0% hemolytic at 1.25μM',
#  '0% hemolysis up to 8μM',
#  '1.5 ±1.4%hemolytic at 100μM',
#  '10% hemolytic at 4 μg/mL',
#  '~90% hemolysis at 80μM',
#  '12-25% hemolysis at 80 μg/ml ',
#  '0.3% hemolysis at 80µg/ml',
#  '~7% hemolytic at 256mg/ml',
#  'HC50 =290µM',
#  '0.05 fractions hemolysis at 5.0μM  ',
#  '35% hemolysis at 200μM',
#  '7% hemolysis at 1000μg/ml',
#  '0% hemolytoc at 100μM (non-hemolytic)',
#  '5.9% hemolytic at 50μg/ml',
#  '93% hemolysis at 100µM ',
#  '2.48% hemolysis at 100μM',
#  'EC50 =4.5 X10-5M',
#  '3.4 ±1.3% hemolytic at 100μM',
#  'LC50 = 210µM',
#  '0% hemolysis upto 8μM',
#  '3.1% hemolytic at 100 μ g/mL',
#  '81 ±  5.3% hemolysis at 360µM',
#  'Little hemolysis upto 200µg/ml',
#  '100% hemolysis at 200 µM',
#  'LC50 =95.7μM ',
#  '7.2% hemolysis at 0.125mg/ml',
#  '<10% hemolytic at 256mg/ml',
#  'Conc. Required for hemolysis =1.75nmols',
#  '4.96% hemolysis at 12.5μg/ml  ',
#  '90% hemolysis at 100 µM',
#  '80-85% hemolysis at 100 µg/ml',
#  '100% hemolytic at 40μM ',
#  'IC50 =80μM',
#  'HD50 =50μM',
#  '~20% hemolysis at 10µM',
#  '22% hemolysis at 100μM',
#  '17% hemolysis at 500μg',
#  'HD50 =1.02±0.04mM',
#  '100% hemolysis at 120μM',
#  '15% hemolysis at 100µM ',
#  'LC50 =0.5±0.1μM',
#  '0% hemolysis at 200 μg/ml (non-hemolytic)',
#  'MHC = 32μg/mL',
#  'LC50 =5±1μM',
#  '0% hemolysis at 75μg (non hemolytic)',
#  '5.13% hemolysis at 25μg/ml  ',
#  '~0% hemolysis at 200μM (non-hemolytic)',
#  '25% hemolysis at 6μM',
#  '5% hemolysis upto 200µg/ml',
#  '0% hemolysis at 1-100μM  ',
#  '~9% hemolytic at 60μM',
#  'LD50 = 110µM',
#  '100% hemolysis at 1μM   ',
#  '62.5% hemolytic at 40μM ',
#  'HC50 =14μM  ',
#  '22% hemolysis at 50µM',
#  'HC50 = 125µM',
#  '37±6% hemolysis at 50µg/ml',
#  '37% hemolysis at 100 µg/ml',
#  '~2% hemolysis at 0.8μM  ',
#  '4.3±0.1% hemolytic at 25μM',
#  '7.5% hemolysis at 100μM',
#  '>30% hemolysis at 200g/l',
#  'LC50 =55μM',
#  '~45% hemolysis at 10μM',
#  '71±2.3% hemolysis at 100µM',
#  '0.13% hemolysis at 25μg/ml',
#  'IC50 =45μM',
#  '0% hemolytic upto 100μM  (non-hemolytic)',
#  '~20% hemolysis at 100μg/ml ',
#  '~20% hemolysis upto 80µg/ml',
#  'EC50 = 880000 nM',
#  'LD50=12.6µM',
#  '4.5% hemolytic at 6μM',
#  '0% hemolysis upto 500 μg/mL (Non hemolytic)',
#  '15% hemolysis at 120μM compared with melittin',
#  '5.3% hemolytic at 10μM',
#  'MHC =50μg/ml',
#  '3.0% hemolysis at 80 μg/ml',
#  '0.07% hemolysis at 10μg/ml',
#  '~63%  hemolysis at 100µM',
#  '29% hemolysis at 3.1µM',
#  'HC50 = 37.3± 1.4 μmol/L',
#  '10% hemolysis at 50μg/mL',
#  '>90% hemolysis at 25µM ',
#  '3±1% hemolysis at 50µM',
#  'LD50 = 480µM',
#  '11% hemolysis at 75μg',
#  'LD50 =0.1 μM',
#  '~ 90% hemolysis at 200µg/ml',
#  '0.28 fractions hemolysis in 15μM  ',
#  '0.08 fractions hemolysis at 15μM ',
#  '90% hemolysis at 50μM',
#  '71% hemolytic at 100μM',
#  '2.4% hemolysis at 40μg/ml',
#  'EC25 =2350μM',
#  '0% hemolytic at 100μg/ml (non-hemolytic)',
#  'No hemolysis at 0.8μM(non hemolytic)',
#  '40% hemolysis at 10µM',
#  '5.13% hemolysis at 50μg/ml  ',
#  'EC50 =50 μM ',
#  '0.02 fractions hemolysis at 5.0μM  ',
#  '~63%  hemolysis at 50µM',
#  'HC50 =52μM',
#  'HD50  =1.0x102μM',
#  'HC50 = 180µM',
#  'zone of inhibition (4 mm) at 0.4-0.5mM',
#  '97% hemolytic at 40μM',
#  '0.19 fractions hemolysis at 5.0μM  ',
#  'HC50 = 43.5μg/ml',
#  'EC50 = 10μM',
#  'Hemolytic at  960µM',
#  '0% hemolysis at 0.78μM',
#  '4% hemolysis at 500μg/ml',
#  '-0.6 ± 1.6% hemolytic at 100μM',
#  '~95% hemolysis at 30µM',
#  '0.07 fractions hemolysis at 15μM  ',
#  '3.0% hemolytic at 50μg/ml',
#  '0% hemolysis at 25μM',
#  '25% hemolysis at 100μg/ml  ',
#  '-0.4 ± 0.5%hemolytic at 100μM',
#  'LC50 = 180µM',
#  'MHC = 250 μg/mL ',
#  '>100% hemolysis at 10µM',
#  'EC50 = 1 µM',
#  '11% hemolysis at 50µM',
#  'Hemolytic 645µM',
#  'LD50 >400μM',
#  '30% hemolysis at 200g/l',
#  '100% hemolysis at 100μM',
#  '25% hemolytic at 6μM',
#  '7.26% hemolysis at 200μg/ml  ',
#  '35% hemolysis at ',
#  'EC50 = 1514µM',
#  '17.8%  hemolysis at 10µM',
#  '0.4% hemolytic at 100mg/mL ',
#  '85% hemolysis at 75μg',
#  '100% hemolysis at 10-3 M',
#  'LC50 =39μM',
#  '>2-3% at ≥16μM ',
#  '2.2% hemolytic at 100μM',
#  '1.1±1.0% hemolytic at 25μM',
#  '85% hemolysis at 100μM ',
#  'zone of inhibition (3 mm) at 0.4-0.5mM',
#  '0% hemolysis at 100 µg/ml (non-hemolytic)',
#  '2% hemolysis at 200μg/ml',
#  '15.5% hemolysis at 100μM',
#  '81% hemolysis at 32μM',
#  '0.27 fractions hemolysis at 15μM  ',
#  '45% hemolysis at 3.125μM',
#  '2.5% hemolysis at 200µg/ml',
#  '0.2 fractions hemolysis at 5.0μM  ',
#  '4% hemolysis at 200µM',
#  '19% hemolysis at 5μM',
#  '36.37% hemolysis at 200μg/ml  ',
#  '59.1% hemolysis at 50µM',
#  '54 ±0.1% hemolytic at 250μM',
#  '100% hemolysis at 14μg/ml',
#  '10% hemolysis at 25µM',
#  'MHC=8μg/ml',
#  'EC50 =95.92μM',
#  'LD50 = 25µM',
#  '20.86% hemolysis at 100μg/ml  ',
#  '27.5% hemolytic at 40μM ',
#  '1.4±0.3% hemolysis at 2.7μM',
#  'LC50 =100μM',
#  'MHC = 3.0x10-5 g/ml',
#  '24% hemolytic at 10μM',
#  'MHC = 2.8x10-3 g/ml',
#  'LC50 ~110µM ',
#  '5.47% hemolysis at 63μg/ml  ',
#  '4% hemolysis at 100µM',
#  'IC50 =44μM',
#  'HD50  =4.23±1.06mM',
#  '32±7% hemolysis at 50µg/ml',
#  'LD50 >500µM',
#  '74% hemolysis at 6.25µM ',
#  '~4% hemolysis at 20μM',
#  'LD50 =30μM',
#  'LD50 = 24µM',
#  '<20% hemolysis at 200μM',
#  '10% hemolysis at 6μM',
#  '1% hemolysis upto 200μg/ml',
#  '88.6% hemolysis at 100µM',
#  'MHC = 19.6 μM',
#  '7.6% hemolysis at 100µM',
#  'LC50 >200μM',
#  '14.92% hemolysis at 100μg/ml  ',
#  'EC50 =7.8μM',
#  '30% hemolysis at 60μg/ml',
#  '86% hemolysis at 100µM',
#  '7% hemolysis at 1μM ',
#  '2.5% hemolytic at 25μg/ml',
#  '13% hemolysis at 25µM',
#  '18% hemolysis at 500μg',
#  '66.5% hemolysis at 80µg/ml',
#  'LC50 =40μM',
#  '1.7% hemolysis at 20μg/ml',
#  '100% hemolysis at 7μM',
#  '91% hemolysis at 75μg',
#  '0-3% hemolysis upto 80 μg/ml',
#  'HC50 >64μM',
#  '1.9% hemolysis at 80µg/ml',
#  'LD50 =50μM',
#  '1% hemolysis at 200µM',
#  '>40% hemolysis at 1μM',
#  '~10% hemolysis at 100μg/ml ',
#  '<50% hemolysis at 30µM',
#  '100% hemolysis at 75μg',
#  '47% hemolysis at 25μg',
#  'Conc. Required for hemolysis =1.1nmols',
#  '0.9±0.1% hemolysis at 11.1μM',
#  '22% hemolysis at 50μM',
#  '0% hemolysis upto 2.013 mM (non-hemolytic)',
#  'No hemolysis (non hemolytic)',
#  '0.19 fractions hemolysis at 15μM  ',
#  '5.76% hemolysis at 100μg/ml  ',
#  'LD50 =150μM',
#  '75%  hemolysis at 100µM',
#  '3.40% hemolysis at 80μg/ml',
#  '35% hemolysis at 50μM',
#  'MHC >200μg/ml',
#  '>40% hemolysis at 10-4 M ',
#  '0.01 fracions Hemoysis at 0.5μM   ',
#  '0% hemolysis at 40μM',
#  '57.58% hemolysis at 200μg/ml  ',
#  '1% hemolysis at 200 μg/ml',
#  '4% hemolysis at 200μg/ml',
#  '2.6% hemolysis at 10μM',
#  'Non-hemolytic upto 50 μg/mL ',
#  '5% hemolysis at 80μg/ml',
#  '<80% hemolytic at 25μM at pH 8 ',
#  ' 41% hemolysis at 40µM  ',
#  'LD50 =14μM',
#  '0% hemolysis at 100μg/ml (non hemolytic)',
#  '5.19% hemolysis at 200μg/ml  ',
#  '3.5% hemolysis at 25µg/ml',
#  '20% hemolysis at 80μM',
#  '75% hemolytic at 100μM',
#  'No hemolysis at 50µM (non-hemolytic)',
#  'LC50 =86.99μM',
#  '2% hemolysis at 200μg/ml ',
#  '20% hemolysis at 40μM',
#  '>20% hemolysis at 10µM',
#  '50-60% hemolysis at 80μg/ml',
#  '10% hemolysis at >400μM',
#  'LD50 = 400µM',
#  '21.0% hemolysis at 180µM ',
#  'HD50  =2.00±0.12mM',
#  '1% hemolysis at 10μM',
#  '3.1% hemolysis at 25μM',
#  '11% hemolysis at 50μM  ',
#  '52% hemolytic at 10 μg/mL',
#  '46% hemolysis at 100µM',
#  'MHC =250μg/ml',
#  'HC50 =14μM',
#  '90% hemolysis at 200μM',
#  '5.01% hemolysis at25μg/ml  ',
#  '7% hemolysis at 50μM  ',
#  '27.3% hemolysis at 100µM',
#  '43% hemolysis at 120μM compared with melittin',
#  '2% hemolysis at 75μg',
#  '100% hemolysis at >70µM ',
#  'MHC =12.5μg/ml',
#  'HD50 =30μM',
#  '0.06 fractions hemolysis at 15μM  ',
#  '50-60% hemolysis at 10-3 M',
#  '>75% hemolysis at 30µM',
#  '65-70% hemolysis at 10 µg/ml',
#  '60.8% hemolysis at 100μM ',
#  'MHC =100μg/ml',
#  '5.19% hemolysis at 12.5μg/ml  ',
#  '~30% hemolysis at 50μM',
#  '<5% hemolysis at 5μM',
#  'EC50 = 5200µM',
#  '1.92% hemolysis at 80μg/ml',
#  '13.8% hemolysis at 100µM',
#  '4% hemolysis at 3.12µM',
#  '~6% hemolytic at 256mg/ml',
#  '0.18 fractions hemolysis at 15μM  ',
#  'LD50 =2.5 μM',
#  '10% hemolytic at 6μM',
#  '5.5% hemolysis at 50µg/ml',
#  '0.18 fractions hemolysis at 5.0μM  ',
#  '80% hemolytic at 256 μg/mL',
#  '40% hemolysis at 40μM  ',
#  '11±4.6% hemolysis at 360µM',
#  '0-5% hemolysis at 320μg/ml',
#  'LD50 >500 μM',
#  '0.7±0.3% hemolysis at 5.5μM',
#  '~4% hemolysis at 30μM',
#  'MHC = 3.44μM ',
#  'LD50 =45μM',
#  '0% hemolysis at 50µM',
#  '0.36% hemolysis at 200μg/ml',
#  'EC50 =354µg/ml',
#  '0% hemolysis at 140µg/ml (non-hemolytic)',
#  'HC10  = 15.4 μg/ml',
#  '4.72% hemolysis at 50μg/ml  ',
#  '100% hemolytic at 100μg/ml',
#  '5.1% hemolytic at 10μM',
#  '85% hemolysis at 12.5μM',
#  'HD50 =134.0μM  ',
#  '2.24% hemolysis at 100μM',
#  '1.5% hemolysis at 0.0625mg/ml',
#  '36% hemolysis at 50μM  ',
#  '5.13%hemolysis at 12.5μg/ml  ',
#  '55% hemolysis at 10μM',
#  'Hemolytic activity expresssed as the initial rate (∆A/∆t, min- 1) i.e. at above 100 µM activity is  above 0.010 min-1',
#  'HD50 =11.7μM ',
#  'MHC =62.5μg/ml',
#  'HC50 =5μM',
#  '8% hemolysis at 16μM',
#  '5% hemolysis at 500μg/ml',
#  'HD50 =2.37±0.08mM',
#  '34.29% hemolysis at 100μg/ml  ',
#  'LC50 =180μM',
#  '0% hemolysis upto 200μg/ml (non hemolytic)',
#  '1.16% hemolysis at 100μM',
#  'LD50 > 480µM',
#  'HD50  =28.07±3.06mM',
#  '~70% hemolysis at 30μM',
#  'EC50 = 14.5μM',
#  '0.82% hemolysis at 100µM ',
#  '100% hemolysis at 5 μM',
#  '25% hemolysis at 80μg/ml',
#  '0±1.7% hemolytic at 25μM',
#  'EC50 =7.98μM',
#  '2% hemolysis at 50μg/ml ',
#  '57.1% hemolysis at 1mg/ml',
#  '~20% hemolysis at 50μM',
#  '42% hemolytic at 100 µg/ml',
#  '30% hemolysis at 150μM',
#  'Non-hemolytic',
#  '20-30% hemolysis at 50μM',
#  '51.3±1.6% hemolytic at 25μM',
#  'MHC= 250 μg/mL ',
#  '60% hemolysis at 10µM',
#  '>75% hemolysis at 20μM',
#  '1.2% hemolysis at 200µg/ml',
#  '1.03% hemolysis at 100μM',
#  'HC50  = 4µM ',
#  'MHC = 15 μM',
#  '22% hemolytic at 50μM',
#  'MHC = 53.75μM',
#  '100% hemolysis at 50μM  ',
#  '8.5% hemolysis at 50µM',
#  'HD50 =82.6μM  ',
#  '12.0±1.8% hemolytic at 25μM',
#  '73% hemolysis at 25μg',
#  '>2-3% at ≥20μM ',
#  '40±4.0% hemolysis at 50µM',
#  'no hemolysis upto <400μg/ml',
#  'LD50 =0.8 μM',
#  'LD50 =25μM',
#  '~2% hemolytic at 6μM ',
#  '70-75% hemolysis at 160μg/ml',
#  '0% hemolysis upto 5μM',
#  'HC10  = 4500 μg/ml',
#  '100% hemolysis at >0.5 mg/ml',
#  '5% hemolysis at 10μM',
#  '11.63% hemolysis at 6.0μg',
#  '3% hemolysis at 25μg/ml ',
#  '6% hemolysis at 100µM ',
#  'No hemolysis at 200nM',
#  '48% hemolysis at 10µM',
#  '11.62% hemolysis at 100µM',
#  '7.1% hemolytic at 10μM',
#  '5.4% hemolytic at 12.5μg/ml',
#  '50% hemolysis at 0.72mg/ml',
#  '50% hemolysis at 12.5μM',
#  'HC50 >92μM',
#  'Little hemolysis at 200mg/ml',
#  '75% hemolysis at 100µM',
#  '5.19% hemolysis at 25μg/ml  ',
#  '55-60% hemolysis at 80 µM',
#  '100% hemolysis at 64μM  ',
#  'EC50 = 1510µM',
#  '5.4% hemolytic at 10μM',
#  '0% hemolysis at 125μM',
#  ' LD50 = 42µM',
#  '60% hemolysis at 40μM  ',
#  '4% hemolysis at 100μM',
#  '8% hemolysis at 64μM  ',
#  '70.3% hemolysis at 80µg/ml',
#  'No hemolysis at 6µM (non-hemolytic)',
#  '50% hemolysis at 450µM',
#  'EC50 = 1420µM',
#  'LD50 =90μM',
#  'EC50 = 195μg/ml',
#  'EC50 >300μM',
#  '50% hemolysis at 100µM ',
#  '90.5±0.8% hemolysis at 44.5μM',
#  '20%  hemolysis at 1mM',
#  'Non-hemolytic up to 250 μM',
#  'LC50 =119µM ',
#  '13% hemolysis at 75μg',
#  '28% hemolysis at 0.4μM  ',
#  '37% hemolytic at 100μg/ml',
#  'HD50  =2.07±0.05mM',
#  '1% hemolysis at 80μg/ml ',
#  '10% hemolysis at 50μg/ml',
#  'No or little hemolysis upto 800μM',
#  'MHC ≥200μg/ml',
#  '100% hemolytic at 100 µg/ml ',
#  '12.4% hemolysis at 0.5mg/ml',
#  '17% hemolysis at 200µM',
#  '2% hemolysis at 100μg/ml',
#  '>50% hemolysis at 40μM',
#  '0.01% hemolysis at 10µg/ml',
#  '0% hemolysis at 200μM',
#  'MHC >500μg/mL ',
#  '4.78% hemolysis at 6.3μg/ml  ',
#  'EC50 =3μM  ',
#  '1.1% hemolysis at 60µg/ml',
#  '4.73% hemolysis at 50μg/ml   ',
#  '9.5% hemolysis at 100μM',
#  '1.5-2.3% hemolysis at 3-100 μg/ml ',
#  '>95% hemolysis at 30μM',
#  '50% hemolysis at 274µM',
#  'MHC =31.3μg/ml',
#  'zone of inhibition (2 mm) at 0.4-0.5mM',
#  '3% hemolysis at 50μM  ',
#  '3.5% hemolytic at 1.25μM',
#  '44% hemolysis at 25µM',
#  'Lethal concentration =0.5μM',
#  '50% hemolysis at >400μM',
#  '50% hemolysis at 50μM',
#  '10% hemolysis at 6.2μM',
#  'LD50 = 350µM',
#  'MHC =15.6μg/ml',
#  'LD50 =200μM',
#  'LD50 = 220µM',
#  'LC50 = 160µM',
#  '83±13.5% hemolysis at 100µM',
#  '6.0% hemolysis at 100µM',
#  'MHC= 3.46μM ',
#  '92%  hemolysis at 6.25μM',
#  '45% hemolysis at 100µM',
#  '2% hemolytic at 1.25μM',
#  '5.99% hemolysis at 100μg/ml  ',
#  '2.8±0.3% hemolytic at 25μM',
#  '7.6% hemolysis at 0.5mg/ml',
#  '1% hemolysis at 200μg/ml ',
#  'EC50 >1000µg/ml',
#  'HC50= 17.13 µg/mL ',
#  'LD50 =100μM',
#  '<10 HU/mg',
#  '0.1% hemolytic at 25.0μg/ml',
#  '45% hemolysis at 64μM  ',
#  'MHC =6.3μg/ml',
#  'LC50  = 82μM',
#  '100% hemolytic at 100μM ',
#  '17.1% hemolysis at 80µg/ml',
#  '5% hemolysis at 400μM',
#  '0% hemolysis up to 32μM',
#  '100% hemolytic at 0.4μM &  23μM',
#  'HC50 >200μg/ml',
#  'HC50 = 210µM',
#  '9.9% hemolysis at 100μM',
#  'HD50 =77.2μM  ',
#  'LC50 = 145 µM',
#  '41% hemolysis at 200μg/ml ',
#  'HC50 = 200µM',
#  '22±1.3% hemolysis at 50µM',
#  'HC50 = 0.6± 0.1 μmol/L',
#  '~5% hemolytic at  128μmol/L',
#  ' LC50 <5µM',
#  'EC50 = 7-14μg/ml',
#  '20% hemolysis at 100μg/ml',
#  '21±5% hemolysis at 50µg/ml',
#  '4.61% hemolysis at 200μg/ml  ',
#  'HL50 = 2.5 μM at pH 7.4 ',
#  'LD50 = 22µM',
#  ' LD50 = 500µM',
#  '94% hemolysis at 24μM',
#  '95% hemolysis at 0.77mM  ',
#  '50.4% hemolysis at 100µM',
#  '11.5% hemolytic at 40μM ',
#  '27% hemolysis at 200μM ',
#  '65% hemolysis at 80μg/ml',
#  '100% hemolysis at ~20μM',
#  '29% hemolytic at 6μM',
#  '0.81% hemolysis at 16μg/ml',
#  'EC25=24μM',
#  '4.44% hemolysis at 6.3μg/ml  ',
#  '6% hemolytic at 1.25μM',
#  '~45% hemolysis at 1μM',
#  'IC50 >100μM',
#  '90-100% hemolysis at 50μg/ml',
#  'EC50 =430μM',
#  'EC50 =0.37μM',
#  'EC50 = 220µg/ml',
#  '71% hemolytic at 200μM',
#  'HD50 = 20.0±1.1μM  ',
#  '66.2% hemolysis at 100µM',
#  '7.8% hemolysis at 1mg/ml',
#  '0% hemolysis at 200μg/ml (non-hemolytic)',
#  '0.26 fractions hemolysis at 15μM  ',
#  '83% hemolysis at 50µM',
#  '4.90% hemolysis at 6.3μg/ml  ',
#  '5.36% hemolysis at 100μg/ml  ',
#  '4.5% hemolysis at 100µM',
#  'LC50   >200μM',
#  'LC50 = 40µM',
#  'LC50 = 100µM',
#  'No hemolysis at 10μM (non hemolytic)',
#  '<70% hemolytic at 25μM at pH 6  ',
#  '5.01% hemolysis at 12.5μg/ml  ',
#  '47.72% hemolysis at 200μg/ml  ',
#  '1.98% hemolysis at 64µM',
#  '15% hemolytic at 40μM ',
#  'LC50 = 29.7µM ',
#  '0% hemolytic at 200μM',
#  '40% hemolysis at 1µM',
#  '4.44% hemolysis at 25μg/ml  ',
#  '2% hemolysis at 200µM',
#  '50% hemolysis at ~20μM',
#  '1.8% hemolysis at 100µM',
#  '5.01% hemolysis at 200μg/ml  ',
#  'HC50 =18µM',
#  '2.1±0.4% hemolytic at 25μM',
#  'LC50 =220μM',
#  '92% hemolysis at 24μM',
#  '0.0 fractions hemolysis at 0.5μM  ',
#  '4.84% hemolysis at 100μg/ml  ',
#  '1.3% hemolysis at 10μg/ml',
#  'LC50 =2.3±0.3μM',
#  '0% hemolysis at 3 - 50μM  (non-hemolytic)',
#  '100% hemolysis at 50µg/ml',
#  '22±2.8% hemolysis at 100µM',
#  '>50% hemolysis at 80 μg/ml ',
#  '0% hemolysis at ≥200μM',
#  '97 % of hemolysis at 50mM',
#  'IC50 >50μM  ',
#  '5.8% hemolytic at 25μg/ml',
#  '10.78% hemolysis at 25μg/ml  ',
#  '28% hemolysis at 20µM',
#  '43% hemolysis at 12.5µM',
#  'LC50  = 69μM',
#  'HC50 =4μM',
#  'LC50 =28.34μM ',
#  '0.12 fractions hemolysis at 5.0μM  ',
#  '30-40% hemolysis at 50 µM',
#  '10.0% hemolysis at 80 μg/ml',
#  'MHC <400μg/ml',
#  'EC50 = 3950µM',
#  'LC50 =1.2±0.4μM',
#  '40-50% hemolysis at 100μM',
#  '~10% hemolysis  at 100µM',
#  ' LD50 = 330µM',
#  '29% hemolysis at 100μg/ml ',
#  '5±0.1% hemolysis at 360µM',
#  '1.8% hemolysis at 40µg/ml',
#  '0% hemolysis at 40μM  (non-hemolytic)',
#  '13% hemolysis at 50μM  ',
#  '100% hemolysis at >330μM',
#  '>10% hemolytic at 200μM ',
#  'HC50 = 7µM',
#  '100% hemolysis at 5μg/ml',
#  'HL50 = 3.0 at pH 7.4',
#  '38% hemolysis at 25μg',
#  'EC25=159μM',
#  '14% hemolysis at 100µg ml-1',
#  '4% hemolysis at 75μg',
#  'LD50 =12μM',
#  '29% hemolysis at 50 μM',
#  '11.2±1.5% hemolysis at 50µM',
#  'HD50 =5.5μM',
#  'Lethal concentration =17.0μM',
#  'No hemolysis upto 10μM (non hemolytic)',
#  '39% hemolytic at 40μM',
#  '9% hemolysis at 1.56μM',
#  'LD50 =250μM',
#  '37.4% hemolytic at 100μM',
#  'HD50 =4.37±0.60mM',
#  '~30% hemolysis at 200μM',
#  '30% hemolysis at 1.5μM',
#  '0.7% hemolysis at 0.0625mg/ml',
#  'EC50 >40μM',
#  '50% hemolysis at 90µM',
#  'EC25=20μM',
#  '9±2.2% hemolysis at 50µM',
#  '0.09 fractions hemolysis at 0.5μM  ',
#  'LC50  = 30μM',
#  '17.58% hemolysis at 50μg/ml  ',
#  '4.73% hemolysis at 50μg/ml  ',
#  'LC50 =38μM',
#  '4.84% hemolysis at 6.3μg/ml  ',
#  '6% hemolysis at 25μM',
#  '6% hemolysis at 50μM  ',
#  '29% hemolysis at 50μM',
#  '10.3% hemolysis at 10µM ',
#  'IC50 =9.3μM  ',
#  '~50% hemolysis at 100µM',
#  'MHC  >1000.0μg/ml',
#  '100% hemolysis at 8μg',
#  '8% hemolysis at 100 µg/ml',
#  '1% hemolysis at 50µM',
#  'HD50 =157.6μM  ',
#  '0.3 ±0.9% hemolytic at 100μM',
#  '2% hemolysis at 10μM',
#  '25.8% hemolysis at 10µg/ml',
#  '0.21% hemolysis at 100μg/ml',
#  '14±2.9% hemolysis at 100µM',
#  'LC50 =1,186μM ',
#  'IC50 =6.4μM  ',
#  '>25% hemolysis at 200g/l',
#  '14.8% hemolysis at 20µM ',
#  '0.8% hemolysis at 80µg/ml',
#  '17.6±2.2% hemolysis at 50µg/ml',
#  '0.3% hemolytic at 3.4mg/ml',
#  'MHC = >6.8x10-3 g/ml',
#  'IC50 =13μM',
#  '0.0 fractions hemolysis at 5.0μM  ',
#  '~80% hemolytic at 25μM at pH 8',
#  'MHC =  64μg/mL ',
#  '77% hemolysis at 100μM',
#  '12% hemolysis at 80μg/ml',
#  'MHC =200μM',
#  '3% hemolysis at 100µg ml-1',
#  '2.7% hemolytic at 10μM',
#  '19.8% hemolysis at 100µM',
#  'LC50 >500μM',
#  '64.43% hemolysis at 200μg/ml  ',
#  '0% hemolysis at 1000μg (non hemolytic)',
#  'LC50 =57±3μM',
#  '0.49% hemolysis at 200μg/ml',
#  '0.45 fractions hemolysis at 15μM  ',
#  '>20% hemolysis at 25µM',
#  '40±3.5% hemolysis at 50µM',
#  '3% hemolysis at 1.5μM',
#  '65% hemolysis at 100µM',
#  '80-85% hemolysis at 15 µM',
#  '~90% hemolysis at 100μg/ml',
#  '0.59% hemolysis at 100µM ',
#  '>80% hemolytic at 25μM at pH 8 ',
#  '17.5±1.1% hemolysis at 11.1μM',
#  '0% hemolysis at 100μg/ml',
#  'MHC = 3.44μM',
#  'Hemolytic activity expresssed as the initial rate (∆A/∆t, min- 1) i.e. at above 100 µM activity is less than 0.002 min-1',
#  '4.61% hemolysis at 6.3μg/ml  ',
#  'HD50 =164.0μM  ',
#  '0% hemolysis at 50μM  ',
#  '70.2% hemolysis at 80 μg/ml',
#  '<0.3% hemolysis at 100µM',
#  'HC50 =125μM',
#  '45-50% hemolysis 100 µM',
#  '45-50% hemolysis at 120μM',
#  '68.2% hemolysis at 100µM',
#  '4.90% hemolysis at 200μg/ml  ',
#  '>80% hemolysis at 30μM',
#  'EC50 = 3700µM',
#  '5.9% hemolysis at 100μM',
#  '0.2% hemolysis at 200μg/ml',
#  'LC50 =2μM',
#  '21.4% hemolysis at 64μM  ',
#  'HC50 =3μM',
#  '100% hemolysis at 80μM',
#  '24% hemolysis at 75μg',
#  '10% hemolysis at 160μg/ml',
#  '<0.5% hemolysis upto 500μg/ml',
#  'HC50 >300μM',
#  'HC50 =180μM',
#  '>70% hemolysis at 20μM',
#  '5.13% hemolysis at 6.3μg/ml  ',
#  '85±7.4% hemolysis at 100µM',
#  '4.84% hemolysis at 50μg/ml  ',
#  'MHC <<81μM',
#  'HD50 =157.4μM  ',
#  'Lethal concentration calculated from zone of inhibition  >200μM ',
#  'MHC = 16μg/mL',
#  'Little hemolysis at 100µg/ml',
#  'Hemolytic at 110 µM',
#  '0% hemolysis upto 50µM (Non hemolytic)',
#  'HC50  >200μg/ml',
#  'zone of inhibition not detected at 0.4-0.5mM',
#  '3.2 HU/mg',
#  '0.1% hemolysis at 50μg/ml',
#  'EC50 =6μM  ',
#  'LD50 ~2.1µM',
#  '39.9% hemolysis at 50 µM',
#  '0.0 fractions hemolysis 5.0μM  ',
#  '58% hemolysis at 75μg',
#  '25% hemolysis at 100 μM',
#  'no hemolysis upto <400μM',
#  'LD50 = 80µM',
#  'HC10  = 44 μg/ml',
#  '>10% hemolysis at 100μg/ml ',
#  '50% hemolysis at 40 µM',
#  'LC50 ~20µM',
#  'MHC = 101.4μM',
#  '65.5±7.7% hemolysis at 50µg/ml',
#  'HD50=110μg/ml',
#  '0-5% hemolysis at 100µM',
#  '48% hemolytic at 6μM',
#  '0% hemolytic at 6.25μg/ml',
#  '0.40% hemolysis at 200μg/ml',
#  'EC25=307μM',
#  '48% hemolysis at 6μM',
#  'Increased hemolysis at 3-100μg/ml ',
#  '60% hemolysis at 100 µM',
#  'HC50 > 500',
#  'HD50 =117.3μM  ',
#  '50% hemolysis at 296µM',
#  '<10% hemolysis at 100µg/ml',
#  ...}

# %%
dataframe_data.head()
# Out:
#   Hemolytik ID      PMID  YEAR                      SEQUENCE LENGTH      NAME  \
# 0         1003  10660589  2000  ALWDTLLKKVLKAAAKAALNAVLVGANA     28     D4-S4
# 1         1004  10660589  2000  ALWDTLLKKVLKAAAKAALDAVLVGANA     28  D4D20-S4
# 2         1005  10660589  2000  ALWMTLLKKVLKAAAKAALKAVLVGANA     28    K20-S4
# 3         1006  10660589  2000  ALWKTLLKKVLKAAAKAALNAVLVGANA     28     K4-S4
# 4         1007  10660589  2000  ALWKTLLKKVLKAAAKAALKAVLVGANA     28  K4K20-S4
#
#   C-ter Modification N-ter Modification Linear/Cyclic Stereochemistry  \
# 0               Free               Free        Linear               L
# 1               Free               Free        Linear               L
# 2               Free               Free        Linear               L
# 3               Free               Free        Linear               L
# 4               Free               Free        Linear               L
#
#   Non-Natural         NATURE         ACTIVITY RBCs SOURCE
# 0        None  Antimicrobial  LC50 =2.3±0.3μM       Human
# 1        None  Antimicrobial      LC50 =5±1μM       Human
# 2        None  Antimicrobial  LC50 =1.2±0.4μM       Human
# 3        None  Antimicrobial    LC50 =2±0.1μM       Human
# 4        None  Antimicrobial  LC50 =0.5±0.1μM       Human

# %%
def check_if_range(value:str)->bool:
    if "-" in value:
        return True
    elif ">" in value:
        return True
    elif "<" in value:
        return True
    elif ">=" in value:
        return True
    elif "<=" in value: 
        return True
    else:
        try:
            tst_ = float(value)
            succeeded = True
        except ValueError:
            succeeded = False
    
    if succeeded:
        return False
    else:
        return True

def get_bounds_from_range(value_range):
    if "-" in value_range:
        n1 = value_range.split("-")[0]
        n2 = value_range.split("-")[1]
    elif ">" in value_range:
        n1 = value_range.split(">")[1]
        n2 = None
    elif "~" in value_range:
        n1 = value_range.split("~")[1]
        n2 = None
    return n1,n2
    
def trim_percentage_values(percentage):
    """
    removes useful information, but information that makes data processing 
    difficult. E.g. ">70%" becomes "70%", or "~80%" becomes "80"
    """
    if not isinstance(percentage, str):
        raise ValueError(f"{percentage=} is not of type string")

    _symbols_to_remove = [">","<","~", "±"]
    new_percentage = percentage
    for _symbol in _symbols_to_remove:
        if (_symbol in percentage) and (_symbol != "±"):
            new_percentage = percentage.split(_symbol)[1]
        elif (_symbol in percentage) and (_symbol == "±"):
            new_percentage = percentage.split(_symbol)[0]
    
    return new_percentage
            

def parse_unique_activity_values(set_of_values):
    # some values are of the form:
    # formA: X% hemolysis at Y*U
    # Units can be
    # -g/l
    # - \mu g/ml
    # - \mu M
    # - nM

    units = ["μM", "μg/ml", "g/l", "nM", "mg/ml"]
    final_units = ["μM","μg/ml"]
    unit_conversions = {
        "μM":(1,"μM"),
        "nM":(10**(-3),"μM"),
        "μg/ml":(1,"μg/ml"),
        "g/l":(10**3, "μg/ml"),
        "mg/ml":(10**3, "μg/ml")
    }
    unit_conversion_coef = {
        "μM_per_nM":10**(-3),
        "μg/ml_per_mg/ml":10**3,
        "g/l_per_mg/ml":1
    }
    output = {"hemolytic at":[],
             "concentration_lower_bound":[],
             "concentration_upper_bound":[],
              "unit":[]
    }
    counter = 0
    for value_ in set_of_values:
        value = value_.strip()
        
        formA = (("hemolysis at" in value) or ("hemolytic at" in value) )
        formB = ('hemolysis upto' in value)

        possible_percents_  = list(range(10,110,10))
        possible_50reports_ = ["EC", "LC", "HC", "LD", "HD"]
        possible_reports_ = []
        formC = False
        for percent_ in possible_percents_:
            for report_ in possible_50reports_:
                if report_+str(percent_) in value:
                    formC = True
                    formC_percent_ = percent_
                    formC_report_  = report_
                    break
            if formC:
                break
            
        if formA: 
            counter += 1
            # first grab the percentage
            percent_value_ = value.split("%")[0]
            percent_value_ = trim_percentage_values(percent_value_)

            # concentration
            concentration_ = value.split("at ")[1]
            new_concentration_ = 1.0
            new_unit_ = ""
            for unit_ in units:
                if unit_ in concentration_:
                    new_concentration_ = concentration_.split(unit_)[0]
                    if check_if_range(new_concentration_):
                        bounds = get_bounds_from_range(new_concentration_)
                        lower_bound_, upper_bound_ = bounds
                    else:
                        # if a bound is not reported
                        lower_bound_ = new_concentration_
                        upper_bound_ = None
                    
                    
                    new_concentration_lower_bound_ = float(lower_bound_) * unit_conversions[unit_][0]
                    if upper_bound_ is not None:
                        new_concentration_upper_bound_ = float(upper_bound_) * unit_conversions[unit_][0]
                    else:
                        new_concentration_upper_bound_ = None
                    new_unit_ = unit_conversions[unit_][1]
                    break
            # print(f"Form A", percent_value_, new_concentration_lower_bound_, new_concentration_upper_bound_, new_unit_)
            print(counter)
        elif formB:
            counter += 1
            # first grab the percentage
            percent_value_ = value.split("%")[0]
            percent_value_ = trim_percentage_values(percent_value_)

            # concentration
            concentration_ = value.split("upto ")[1]
            new_concentration_ = 1.0
            new_unit_ = ""
            for unit_ in units:
                if unit_ in concentration_:
                    new_concentration_ = concentration_.split(unit_)[0]
                    if check_if_range(new_concentration_):
                        bounds = get_bounds_from_range(new_concentration_)
                        lower_bound_, upper_bound_ = bounds
                    else:
                        # if a bound is not reported
                        lower_bound_ = None
                        upper_bound_ = new_concentration_

                    new_concentration_upper_bound_ = float(upper_bound_) * unit_conversions[unit_][0]
                    if lower_bound_ is not None:
                        new_concentration_lower_bound_ = float(lower_bound_) * unit_conversions[unit_][0]
                    else:
                        new_concentration_lower_bound_ = None
                    
                    new_unit_ = unit_conversions[unit_][1]
                        
            # print(f"Form B", percent_value_, new_concentration_lower_bound_, new_concentration_upper_bound_, new_unit_)
        elif formC:
            percent_value_ = formC_percent_
            formC_report_  = report_
            concentration_ = value.split("=")[-1]
            concentration_ = concentration_.strip()
            new_unit_ = ""
            if "2.1x102" in concentration_:
                concentration_ = str(2.1* 10**2)
                new_unit_ = "μM"
            
            print(f"Form C", percent_value_,concentration_, new_unit_, "value=",value)
        else:
            print("===== NO FORM: ",value)

# %% [markdown]
# HCX := minimal concentration inducing X% hemolysis in human erythrocytes. \
# EC50 := concentration required to obtain a 50% effect \
# IC50 := concentration required to inhibit a process by 50% \
# HD50 := concentration causing 50% hemolysis of red blood cells \
# LC50 or LD50 := The value of LD50 for a substance is the dose required to kill half the members of a tested population after a specified test duration. (concentration causing 50% hemolysis in this case)

# %%
parse_unique_activity_values(set(dataframe_data.ACTIVITY))
# Out:
# 2
# 3
# 4
# 5
# Form C 50 77μg/ml  value= HD50=77μg/ml
# 6
# 7
# 8
# 9
# 10
# Form C 50 LD50 > 600µM  value= LD50 > 600µM
# ===== NO FORM:  MHC <81μM
# 11
# 13
# Form C 50 LC50  >100μM  value= LC50  >100μM
# 14
# Form C 50 45000 nM  value= EC50 = 45000 nM
# Form C 10 3840 μg/ml  value= HC10  = 3840 μg/ml
# Form C 50 8.9x103μM  value= HD50  =8.9x103μM
# Form C 10 1.78 μg/ml  value= HC10  = 1.78 μg/ml
# 16
# ===== NO FORM:  MHC =214.81μM
# Form C 50 100µM  value= LD50 = 100µM
# 17
# 18
# Form C 10 203 μg/ml  value= HC10  = 203 μg/ml
# 19
# Form C 50 50μM  value= LC50 =50μM
# Form C 50 80μM  value= EC50 =80μM
# Form C 50 590000 nM  value= EC50 = 590000 nM
# 20
# 21
# 22
# 23
# Form C 10 9350  μg/ml  value= HC10  = 9350  μg/ml
# 24
# 25
# Form C 50 8.7μM  value= HD50 = 8.7μM
# 26
# ===== NO FORM:  Hemolytic activity expresssed as the initial rate (∆A/∆t, min- 1) i.e. at above 100 µM activity is  ~0.002 min-1
# 27
# ===== NO FORM:  MHC =1000 μg/ml
# ===== NO FORM:  0% hemolysis  at 50 µM (non-hemolytic)
# 28
# 29
# Form C 50 27.3µM  value= LC50 = 27.3µM
# 30
# 31
# 32
# 33
# ===== NO FORM:  20% hemolysis 100 µM
# 34
# 35
# 36
# Form C 50 28μM  value= LC50 =28μM
# 37
# 38
# Form C 50 1,467μM  value= LC50 =1,467μM
# Form C 50 10μM  value= LC50 =10μM
# ===== NO FORM:  MHC  <81μM
# 39
# Form C 50 80µM  value= HC50 = 80µM
# 40
# 41
# 42
# Form C 10 13800 μg/ml  value= HC10  = 13800 μg/ml
# 43
# 44
# 45
# 46
# 47
# 48
# Form C 50 38µM  value= LD50 = 38µM
# ===== NO FORM:  No hemolysis (Non hemolysis)
# ===== NO FORM:  MHC =6.92μM
# 49
# Form C 50 EC50  >36μM  value= EC50  >36μM
# 50
# 51
# Form C 50 500µM  value= LC50 = 500µM
# Form C 50 76μM  value= HD50  =76μM
# Form C 50 1,993μM  value= LC50 =1,993μM
# 52
# 53
# 54
# 55
# 56
# ===== NO FORM:  MHC =8μg/ml
# 57
# 58
# 59
# 60
# 61
# Form C 50 75μM  value= HC50 =75μM
# 62
# 63
# 64
# ===== NO FORM:  MHC =50μM
# 65
# 66
# 67
# 68
# 69
# 70
# ===== NO FORM:  Area of inhibition ~25mm2 at 5 nmol
# 71
# 72
# 73
# 74
# 76
# 77
# Form C 50 1950µM  value= EC50 = 1950µM
# 78
# Form C 50 107μM  value= EC50 =107μM
# ===== NO FORM:  MHC = 64μg/mL
# 79
# 80
# 81
# Form C 50 10μM  value= LD50 =10μM
# 82
# 83
# 84
# 85
# ===== NO FORM:  MHC = 5.20 ± 0.02μmol/L
# Form C 50 610µM  value= EC50 = 610µM
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# Form C 50 70μM  value= LC50 =70μM
# 97
# 98
# 99
# 100
# 101
# ===== NO FORM:  4.78% Hmolysis at 6.3μg/ml
# Form C 50 225µM  value= LC50 = 225µM
# 102
# 103
# Form C 50 132µM  value= LC50 =132µM
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# Form C 50 135μM  value= LD50 =135μM
# 114
# Form C 50 LD50 ~0.1µM  value= LD50 ~0.1µM
# Form C 50 210.0 μM value= HD50  =2.1x102μM
# 115
# 116
# Form C 50 7.53±0.19mM  value= HD50 =7.53±0.19mM
# 117
# ===== NO FORM:  IC50 >>100μM
# 118
# 119
# 120
# 121
# Form C 50 2±0.1μM  value= LC50 =2±0.1μM
# Form C 50 46μM  value= EC50 =46μM
# 122
# ===== NO FORM:  Hemolytic activity i.e. 16.6HU/mg
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# 131
# ===== NO FORM:  400μg of peptide can totally lyse 7x108 erythrocytes in 10 min at pH 5.0
# 132
# 133
# 134
# 135
# ===== NO FORM:  MHC =1000μg/ml
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# Form C 50 5.35±0.60mM  value= HD50  =5.35±0.60mM
# 144
# 145
# 146
# 147
# 148
# ===== NO FORM:  IC50 = 26 µM
# Form C 50 338µM  value= EC50 = 338µM
# 149
# ===== NO FORM:  MHC <125 μg/mL
# ===== NO FORM:  MHC = 128μg/mL
# Form C 50 13.1μM  value= EC50 =13.1μM
# 150
# 151
# 152
# Form C 50 HC50 >300µM  value= HC50 >300µM
# 153
# 154
# 155
# 156
# 157
# Form C 10 6140 μg/ml  value= HC10  = 6140 μg/ml
# ===== NO FORM:  Conc. Required for hemolysis =0.6nmols
# 158
# 159
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[246], line 1
# ----> 1 parse_unique_activity_values(set(dataframe_data.ACTIVITY))
#
# Cell In[245], line 111, in parse_unique_activity_values(set_of_values)
#     108 percent_value_ = trim_percentage_values(percent_value_)
#     110 # concentration
# --> 111 concentration_ = value.split("at ")[1]
#     112 new_concentration_ = 1.0
#     113 new_unit_ = ""
#
# IndexError: list index out of range

# %%
print(len(rows))
row_names = ["Hemolytik ID", 
             "PMID", 
             "YEAR", 
             "SEQUENCE", 
             "LENGTH", 
             "NAME", 
             "C-ter Modification", 
             "N-ter Modification", 
             "Linear/Cyclic",
             "Stereochemistry",
             "Non-Natural",
             "NATURE",
             "ACTIVITY",
             "RBCs SOURCE"]
for row in rows:
    for row_name in row_names:
        if row_name in row.text:
            print(row_name, row.text.split(row_name)[1])
# Out:
# 19
# Hemolytik ID 1003
# PMID 10660589
# YEAR 2000
# SEQUENCE ALWDTLLKKVLKAAAKAALNAVLVGANA
# LENGTH 28
# NAME D4-S4
# C-ter Modification Free
# N-ter Modification Free
# Linear/Cyclic Linear
# Stereochemistry L
# Non-Natural None
# NATURE Antimicrobial
# ACTIVITY LC50 =2.3±0.3μM
# RBCs SOURCE Human

# %%
with open(DATABASE_NAME + ".data", 'w') as f:
    f.write(str(amps))
